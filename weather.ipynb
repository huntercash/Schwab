# %% [markdown]
# ## Data Discovery

# %%
import pandas as pd
import os
import numpy as np

# %%
xlsx = pd.read_excel(os.path.join('rawdata/Storm Data Jun-Dec 2011.xlsx'))

# %%
df = pd.DataFrame(xlsx)

# %%
df.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           201110         29        1500         201110       30       800
# 1           201108         28         853         201108       28      1453
# 2           201110         30         120         201110       30       120
# 3           201107         21        1600         201107       21      1800
# 4           201106         28        1650         201106       28      1653
#
#    EPISODE_ID  EVENT_ID           STATE         EVENT_TYPE  ...  \
# 0       57676    350515   NEW HAMPSHIRE         Heavy Snow  ...
# 1       57538    345212   NEW HAMPSHIRE     Tropical Storm  ...
# 2       57676    352765   NEW HAMPSHIRE        Strong Wind  ...
# 3       55656    333708   NEW HAMPSHIRE     Excessive Heat  ...
# 4       54705    328712  NORTH CAROLINA  Thunderstorm Wind  ...
#
#   DAMAGE_PROPERTY  DAMAGE_CROPS             SOURCE  MAGNITUDE  FLOOD_CAUSE  \
# 0          50.00K         0.00K      Amateur Radio        NaN          NaN
# 1          15.00K         0.00K      Amateur Radio        NaN          NaN
# 2           5.00K         0.00K      Amateur Radio       35.0          NaN
# 3           0.00K         0.00K               AWOS        NaN          NaN
# 4           9.00K         0.00K  Emergency Manager       56.0          NaN
#
#   TOR_F_SCALE BEGIN_LAT BEGIN_LON  END_LAT  END_LON
# 0         NaN       NaN       NaN      NaN      NaN
# 1         NaN       NaN       NaN      NaN      NaN
# 2         NaN       NaN       NaN      NaN      NaN
# 3         NaN       NaN       NaN      NaN      NaN
# 4         NaN   34.8108  -79.1868  34.8157 -79.1807
#
# [5 rows x 25 columns]

# %%
df.describe()
# Out:
#        BEGIN_YEARMONTH     BEGIN_DAY    BEGIN_TIME  END_YEARMONTH  \
# count     38356.000000  38356.000000  38356.000000   38356.000000
# mean     201107.553264     13.501304   1305.504719  201107.553264
# std           1.489460      9.200079    680.899719       1.489460
# min      201106.000000      1.000000      0.000000  201106.000000
# 25%      201106.000000      5.000000    929.750000  201106.000000
# 50%      201107.000000     13.000000   1515.000000  201107.000000
# 75%      201108.000000     21.000000   1812.000000  201108.000000
# max      201111.000000     31.000000   2359.000000  201111.000000
#
#             END_DAY      END_TIME    EPISODE_ID       EVENT_ID  \
# count  38356.000000  38356.000000  38356.000000   38356.000000
# mean      16.429190   1598.097090  55223.958077  332577.501851
# std        9.435271    574.259801   2270.263322   14044.131113
# min        1.000000      0.000000  50283.000000  295877.000000
# 25%        8.000000   1400.000000  53563.000000  322929.750000
# 50%       17.000000   1701.000000  55238.000000  333461.500000
# 75%       25.000000   1958.000000  57146.000000  343539.250000
# max       31.000000   2359.000000  79994.000000  588494.000000
#
#        INJURIES_DIRECT  INJURIES_INDIRECT  DEATHS_DIRECT  DEATHS_INDIRECT  \
# count     38356.000000       38356.000000   38356.000000     38356.000000
# mean          0.084576           0.005605       0.010194         0.001486
# std           3.322926           0.360976       0.202643         0.045931
# min           0.000000           0.000000       0.000000         0.000000
# 25%           0.000000           0.000000       0.000000         0.000000
# 50%           0.000000           0.000000       0.000000         0.000000
# 75%           0.000000           0.000000       0.000000         0.000000
# max         301.000000          60.000000      22.000000         4.000000
#
#           MAGNITUDE     BEGIN_LAT     BEGIN_LON       END_LAT       END_LON
# count  23939.000000  28308.000000  28308.000000  28308.000000  28308.000000
# mean      35.007808     39.000270    -89.058626     38.997021    -89.050432
# std       25.317414      4.836674     10.998690      4.835368     10.995543
# min        0.000000    -14.327700   -170.886800    -14.389300   -170.829200
# 25%        1.250000     35.620000    -97.160025     35.613400    -97.160000
# 50%       50.000000     39.440000    -88.270000     39.437450    -88.255000
# 75%       52.000000     42.250000    -80.759875     42.250000    -80.750000
# max      130.000000     65.699100    144.858500     65.750100    144.759000

# %%
df.columns
# Out:
# Index(['BEGIN_YEARMONTH', 'BEGIN_DAY', 'BEGIN_TIME', 'END_YEARMONTH',
#        'END_DAY', 'END_TIME', 'EPISODE_ID', 'EVENT_ID', 'STATE', 'EVENT_TYPE',
#        'CZ_NAME', 'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
#        'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
#        'MAGNITUDE', 'FLOOD_CAUSE', 'TOR_F_SCALE', 'BEGIN_LAT', 'BEGIN_LON',
#        'END_LAT', 'END_LON'],
#       dtype='object')

# %%
df.nunique()
# Out:
# BEGIN_YEARMONTH          6
# BEGIN_DAY               31
# BEGIN_TIME            1400
# END_YEARMONTH            6
# END_DAY                 31
# END_TIME              1397
# EPISODE_ID            6350
# EVENT_ID             38356
# STATE                   65
# EVENT_TYPE              39
# CZ_NAME               2679
# INJURIES_DIRECT         36
# INJURIES_INDIRECT       12
# DEATHS_DIRECT           12
# DEATHS_INDIRECT          4
# DAMAGE_PROPERTY        268
# DAMAGE_CROPS            97
# SOURCE                  36
# MAGNITUDE               99
# FLOOD_CAUSE              6
# TOR_F_SCALE              5
# BEGIN_LAT            11094
# BEGIN_LON            12945
# END_LAT              12123
# END_LON              13974
# dtype: int64

# %% [markdown]
# ## Data Cleanup

# %% [markdown]
# #### Things to analyze
# - Split Begin Year Month
# - create a single column for YYYY-MM-DD for Quandl API comparison for begin, and end

# %%
dtdf = pd.DataFrame(xlsx)
dtdf.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           201110         29        1500         201110       30       800
# 1           201108         28         853         201108       28      1453
# 2           201110         30         120         201110       30       120
# 3           201107         21        1600         201107       21      1800
# 4           201106         28        1650         201106       28      1653
#
#    EPISODE_ID  EVENT_ID           STATE         EVENT_TYPE  ...  \
# 0       57676    350515   NEW HAMPSHIRE         Heavy Snow  ...
# 1       57538    345212   NEW HAMPSHIRE     Tropical Storm  ...
# 2       57676    352765   NEW HAMPSHIRE        Strong Wind  ...
# 3       55656    333708   NEW HAMPSHIRE     Excessive Heat  ...
# 4       54705    328712  NORTH CAROLINA  Thunderstorm Wind  ...
#
#   DAMAGE_PROPERTY  DAMAGE_CROPS             SOURCE  MAGNITUDE  FLOOD_CAUSE  \
# 0          50.00K         0.00K      Amateur Radio        NaN          NaN
# 1          15.00K         0.00K      Amateur Radio        NaN          NaN
# 2           5.00K         0.00K      Amateur Radio       35.0          NaN
# 3           0.00K         0.00K               AWOS        NaN          NaN
# 4           9.00K         0.00K  Emergency Manager       56.0          NaN
#
#   TOR_F_SCALE BEGIN_LAT BEGIN_LON  END_LAT  END_LON
# 0         NaN       NaN       NaN      NaN      NaN
# 1         NaN       NaN       NaN      NaN      NaN
# 2         NaN       NaN       NaN      NaN      NaN
# 3         NaN       NaN       NaN      NaN      NaN
# 4         NaN   34.8108  -79.1868  34.8157 -79.1807
#
# [5 rows x 25 columns]

# %%
dtdf['BEGIN_YM_STR'] = dtdf['BEGIN_YEARMONTH'].astype(str)
dtdf['BEGIN_YEAR'] = df['BEGIN_YM_STR'].str[0:4]
dtdf['BEGIN_MONTH'] = df['BEGIN_YM_STR'].str[4:6]
dtdf['END_YM_STR'] = dtdf['END_YEARMONTH'].astype(str)
dtdf['END_YEAR'] = df['END_YM_STR'].str[0:4]
dtdf['END_MONTH'] = df['END_YM_STR'].str[4:6]
dtdf["START_DATE"] = dtdf["BEGIN_YEAR"].map(str) + "-" + dtdf["BEGIN_MONTH"].map(str) + "-" +\
dtdf["BEGIN_DAY"].map(str)
dtdf["END_DATE"] = dtdf["END_YEAR"].map(str) + "-" + dtdf["END_MONTH"].map(str) + "-" +\
dtdf["END_DAY"].map(str)
df.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           201110         29        1500         201110       30       800
# 1           201108         28         853         201108       28      1453
# 2           201110         30         120         201110       30       120
# 3           201107         21        1600         201107       21      1800
# 4           201106         28        1650         201106       28      1653
#
#    EPISODE_ID  EVENT_ID           STATE         EVENT_TYPE  ...  END_LAT  \
# 0       57676    350515   NEW HAMPSHIRE         Heavy Snow  ...      NaN
# 1       57538    345212   NEW HAMPSHIRE     Tropical Storm  ...      NaN
# 2       57676    352765   NEW HAMPSHIRE        Strong Wind  ...      NaN
# 3       55656    333708   NEW HAMPSHIRE     Excessive Heat  ...      NaN
# 4       54705    328712  NORTH CAROLINA  Thunderstorm Wind  ...  34.8157
#
#    END_LON  BEGIN_YM_STR  BEGIN_YEAR  BEGIN_MONTH END_YM_STR END_YEAR  \
# 0      NaN        201110        2011           10     201110     2011
# 1      NaN        201108        2011           08     201108     2011
# 2      NaN        201110        2011           10     201110     2011
# 3      NaN        201107        2011           07     201107     2011
# 4 -79.1807        201106        2011           06     201106     2011
#
#   END_MONTH  START_DATE    END_DATE
# 0        10  2011-10-29  2011-10-30
# 1        08  2011-08-28  2011-08-28
# 2        10  2011-10-30  2011-10-30
# 3        07  2011-07-21  2011-07-21
# 4        06  2011-06-28  2011-06-28
#
# [5 rows x 33 columns]

# %%
dtdf.DAMAGE_PROPERTY = (dtdf.DAMAGE_PROPERTY.replace(r'[KM]+$', '', regex=True).astype(float) * \
dtdf.DAMAGE_PROPERTY.str.extract(r'[\d\.]+([KM]+)', expand=False).fillna(0).replace(['K','M'], [10**3, 10**6]).astype(int))

# %%
# Whoa a Billion..
dtdf.DAMAGE_CROPS = (dtdf.DAMAGE_CROPS.replace(r'[KMB]+$', '', regex=True).astype(float) * \
dtdf.DAMAGE_CROPS.str.extract(r'[\d\.]+([KMB]+)', expand=False).fillna(0).replace(['K','M','B'], [10**3, 10**6, 10**9]).astype(int))

# %%
dtdf['DAMAGE_PROPERTY'] = dtdf['DAMAGE_PROPERTY'].fillna(0)
dtdf['DAMAGE_CROPS'] = dtdf['DAMAGE_CROPS'].fillna(0)
dtdf.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           201110         29        1500         201110       30       800
# 1           201108         28         853         201108       28      1453
# 2           201110         30         120         201110       30       120
# 3           201107         21        1600         201107       21      1800
# 4           201106         28        1650         201106       28      1653
#
#    EPISODE_ID  EVENT_ID           STATE         EVENT_TYPE  ...  END_LAT  \
# 0       57676    350515   NEW HAMPSHIRE         Heavy Snow  ...      NaN
# 1       57538    345212   NEW HAMPSHIRE     Tropical Storm  ...      NaN
# 2       57676    352765   NEW HAMPSHIRE        Strong Wind  ...      NaN
# 3       55656    333708   NEW HAMPSHIRE     Excessive Heat  ...      NaN
# 4       54705    328712  NORTH CAROLINA  Thunderstorm Wind  ...  34.8157
#
#    END_LON  BEGIN_YM_STR  BEGIN_YEAR  BEGIN_MONTH  END_YM_STR  END_YEAR  \
# 0      NaN        201110        2011           10      201110      2011
# 1      NaN        201108        2011           08      201108      2011
# 2      NaN        201110        2011           10      201110      2011
# 3      NaN        201107        2011           07      201107      2011
# 4 -79.1807        201106        2011           06      201106      2011
#
#   END_MONTH  START_DATE    END_DATE
# 0        10  2011-10-29  2011-10-30
# 1        08  2011-08-28  2011-08-28
# 2        10  2011-10-30  2011-10-30
# 3        07  2011-07-21  2011-07-21
# 4        06  2011-06-28  2011-06-28
#
# [5 rows x 33 columns]

# %%
dtdf.columns
# Out:
# Index(['BEGIN_YEARMONTH', 'BEGIN_DAY', 'BEGIN_TIME', 'END_YEARMONTH',
#        'END_DAY', 'END_TIME', 'EPISODE_ID', 'EVENT_ID', 'STATE', 'EVENT_TYPE',
#        'CZ_NAME', 'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
#        'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
#        'MAGNITUDE', 'FLOOD_CAUSE', 'TOR_F_SCALE', 'BEGIN_LAT', 'BEGIN_LON',
#        'END_LAT', 'END_LON', 'BEGIN_YM_STR', 'BEGIN_YEAR', 'BEGIN_MONTH',
#        'END_YM_STR', 'END_YEAR', 'END_MONTH', 'START_DATE', 'END_DATE'],
#       dtype='object')

# %%
final = dtdf[['EVENT_ID','START_DATE', 'END_DATE', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS','EVENT_TYPE','CZ_NAME', 'STATE', 'SOURCE']]
final.head()
# Out:
#    EVENT_ID  START_DATE    END_DATE  DAMAGE_PROPERTY  DAMAGE_CROPS  \
#
# 29            Thunderstorm Wind                                SHERIDAN
# ...                         ...                                     ...
# 38326         Thunderstorm Wind                                    WILL
# 38327         Thunderstorm Wind                               GRANVILLE
# 38328         Thunderstorm Wind                               CLEVELAND
# 38329         Thunderstorm Wind                                LAWRENCE
# 38330                      Hail                                  MARION
# 38331         Thunderstorm Wind                                 DE KALB
# 38332                      Hail                                 DUNKLIN
# 38333         Thunderstorm Wind                                GUERNSEY
# 38334         Thunderstorm Wind                                  HOWARD
# 38335         Thunderstorm Wind                                ANTELOPE
# 38336  Marine Thunderstorm Wind  PENSACOLA FL TO PASCAGOULA MS OUT 20NM
# 38337         Thunderstorm Wind                                   GRANT
# 38338                 Lightning                                 MADISON
# 38339         Thunderstorm Wind                                 DAVISON
# 38340                      Hail                                BELTRAMI
# 38341         Thunderstorm Wind                                   LEWIS
# 38342         Thunderstorm Wind                               MCCORMICK
# 38343         Thunderstorm Wind                               AROOSTOOK
# 38344         Thunderstorm Wind                               MCPHERSON
# 38345                Heavy Rain                               JEFFERSON
# 38346         Thunderstorm Wind                                   ADAMS
# 38347         Thunderstorm Wind                               LEXINGTON
# 38348              Funnel Cloud                             GRAND FORKS
# 38349  Marine Thunderstorm Wind                           BOSTON HARBOR
# 38350                      Hail                              RUTHERFORD
# 38351         Thunderstorm Wind                                   BRYAN
# 38352         Thunderstorm Wind                                  ELBERT
# 38353         Thunderstorm Wind                               ALEXANDER
# 38354         Thunderstorm Wind                                CABARRUS
# 38355         Thunderstorm Wind                              RENSSELAER
#
#                 STATE                     SOURCE
# 0       NEW HAMPSHIRE              Amateur Radio
# 1       NEW HAMPSHIRE              Amateur Radio
# 2       NEW HAMPSHIRE              Amateur Radio
# 3       NEW HAMPSHIRE                       AWOS
# 4      NORTH CAROLINA          Emergency Manager
# 5      SOUTH CAROLINA            Trained Spotter
# 6            VIRGINIA            Law Enforcement
# 7            VIRGINIA             State Official
# 8            VIRGINIA             State Official
# 9            VIRGINIA            Law Enforcement
# 10             KANSAS            Trained Spotter
# 11             KANSAS                     Public
# 12             KANSAS            Trained Spotter
# 13             KANSAS            Trained Spotter
# 14             KANSAS            Trained Spotter
# 15     SOUTH CAROLINA     Department of Highways
# 16     NORTH CAROLINA            Trained Spotter
# 17            GEORGIA  Official NWS Observations
# 18            GEORGIA  Official NWS Observations
# 19            GEORGIA  Official NWS Observations
# 20            GEORGIA  Official NWS Observations
# 21            GEORGIA  Official NWS Observations
# 22            GEORGIA  Official NWS Observations
# 23            GEORGIA  Official NWS Observations
# 24            GEORGIA  Official NWS Observations
# 25           MISSOURI            Trained Spotter
# 26           MISSOURI            Trained Spotter
# 27            GEORGIA          Emergency Manager
# 28           NEBRASKA                     Public
# 29           NEBRASKA                     Public
# ...               ...                        ...
# 38326        ILLINOIS            Trained Spotter
# 38327  NORTH CAROLINA            Law Enforcement
# 38328        ARKANSAS                     Public
# 38329    PENNSYLVANIA            Law Enforcement
# 38330        ARKANSAS            Trained Spotter
# 38331        ILLINOIS            Trained Spotter
# 38332        MISSOURI            Law Enforcement
# 38333            OHIO          Emergency Manager
# 38334         INDIANA              Amateur Radio
# 38335        NEBRASKA            Law Enforcement
# 38336  GULF OF MEXICO              C-MAN Station
# 38337          KANSAS                     Public
# 38338         ALABAMA            Trained Spotter
# 38339    SOUTH DAKOTA            Law Enforcement
# 38340       MINNESOTA            Trained Spotter
# 38341        MISSOURI                  Newspaper
# 38342  SOUTH CAROLINA                     Public
# 38343           MAINE            Utility Company
# 38344          KANSAS              Amateur Radio
# 38345          OREGON            Trained Spotter
# 38346        ILLINOIS     Fire Department/Rescue
# 38347  SOUTH CAROLINA            Law Enforcement
# 38348    NORTH DAKOTA            Trained Spotter
# 38349  ATLANTIC NORTH                    Mesonet
# 38350  NORTH CAROLINA            Trained Spotter
# 38351         GEORGIA            Law Enforcement
# 38352         GEORGIA            County Official
# 38353  NORTH CAROLINA            County Official
# 38354  NORTH CAROLINA          Emergency Manager
# 38355        NEW YORK             State Official
#
# [38356 rows x 9 columns]

# %%
final.dtypes
# Out:
# EVENT_ID                    int64
# START_DATE         datetime64[ns]
# END_DATE           datetime64[ns]
# DAMAGE_PROPERTY           float64
# DAMAGE_CROPS              float64
# EVENT_TYPE                 object
# CZ_NAME                    object
# STATE                      object
# SOURCE                     object
# dtype: object

# %%
final.describe()
# Out:
#             EVENT_ID  DAMAGE_PROPERTY  DAMAGE_CROPS
# count   38356.000000     3.835600e+04  3.835600e+04
# mean   332577.501851     1.751267e+05  6.089655e+04
# std     14044.131113     5.407172e+06  5.564226e+06
# min    295877.000000     0.000000e+00  0.000000e+00
# 25%    322929.750000     0.000000e+00  0.000000e+00
# 50%    333461.500000     0.000000e+00  0.000000e+00
# 75%    343539.250000     1.000000e+03  0.000000e+00
# max    588494.000000     5.000000e+08  1.050000e+09

# %%
cols = ['DAMAGE_PROPERTY', 'DAMAGE_CROPS']

# %%
final[cols] = final[cols].replace({0:np.nan})

# %%
final.head()
# Out:
#    EVENT_ID START_DATE   END_DATE  DAMAGE_PROPERTY  DAMAGE_CROPS  \
# 0    350515 2011-10-29 2011-10-30          50000.0           NaN
# 1    345212 2011-08-28 2011-08-28          15000.0           NaN
# 2    352765 2011-10-30 2011-10-30           5000.0           NaN
# 3    333708 2011-07-21 2011-07-21              NaN           NaN
# 4    328712 2011-06-28 2011-06-28           9000.0           NaN
#
#           EVENT_TYPE               CZ_NAME           STATE             SOURCE
# 0         Heavy Snow  EASTERN HILLSBOROUGH   NEW HAMPSHIRE      Amateur Radio
# 1     Tropical Storm  EASTERN HILLSBOROUGH   NEW HAMPSHIRE      Amateur Radio
# 2        Strong Wind  EASTERN HILLSBOROUGH   NEW HAMPSHIRE      Amateur Radio
# 3     Excessive Heat  EASTERN HILLSBOROUGH   NEW HAMPSHIRE               AWOS
# 4  Thunderstorm Wind               ROBESON  NORTH CAROLINA  Emergency Manager

# %%
final.to_csv(os.path.join('cleandata','2011_disaster_data.csv'),index=False)
